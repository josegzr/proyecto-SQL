# %% [markdown]
# # 1. limpieza de datos del csv rental

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('../Data/rental.csv', encoding='latin1')
data
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
data['rental_id'] = range(1,len(data)+1)

# %%
data
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        996  2005-05-31 00:08:25          4243          216
# 996        997  2005-05-31 00:16:57          3395          389
# 997        998  2005-05-31 00:25:10          4433          413
# 998        999  2005-05-31 00:25:56          1774          332
# 999       1000  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
data[['Fecha', 'Hora_rental']] = data['rental_date'].str.split(' ', expand=True)
data
data[['year_rental', 'Mes_rental', 'Dia_rental']] = data['Fecha'].str.split('-', expand=True)
data
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        996  2005-05-31 00:08:25          4243          216
# 996        997  2005-05-31 00:16:57          3395          389
# 997        998  2005-05-31 00:25:10          4433          413
# 998        999  2005-05-31 00:25:56          1774          332
# 999       1000  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update       Fecha  \
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53  2005-05-24
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53  2005-05-24
# ...

# %%
data.year_rental.unique()
# Out:
# array(['2005'], dtype=object)

# %%
data_null=[ 'year_rental','rental_date','Fecha']
data.drop(data_null, axis=1,inplace=True)

# %%
data
# Out:
#      rental_id  inventory_id  customer_id          return_date  staff_id  \
# 0            1           367          130  2005-05-26 22:04:30         1
# 1            2          1525          459  2005-05-28 19:40:33         1
# 2            3          1711          408  2005-06-01 22:12:39         1
# 3            4          2452          333  2005-06-03 01:43:41         2
# 4            5          2079          222  2005-06-02 04:33:21         1
# ..         ...           ...          ...                  ...       ...
# 995        996          4243          216  2005-06-02 00:17:25         2
# 996        997          3395          389  2005-06-01 22:41:57         1
# 997        998          4433          413  2005-06-03 06:05:10         2
# 998        999          1774          332  2005-06-08 19:42:56         2
# 999       1000          1498           64  2005-06-06 06:14:31         2
#
#              last_update Hora_rental Mes_rental Dia_rental
# ...

# %%
data[['Fecha', 'Hora_return']] = data['return_date'].str.split(' ', expand=True)
data
data[['year_return', 'Mes_return', 'Dia_return']] = data['Fecha'].str.split('-', expand=True)
data
# Out:
#      rental_id  inventory_id  customer_id          return_date  staff_id  \
# 0            1           367          130  2005-05-26 22:04:30         1
# 1            2          1525          459  2005-05-28 19:40:33         1
# 2            3          1711          408  2005-06-01 22:12:39         1
# 3            4          2452          333  2005-06-03 01:43:41         2
# 4            5          2079          222  2005-06-02 04:33:21         1
# ..         ...           ...          ...                  ...       ...
# 995        996          4243          216  2005-06-02 00:17:25         2
# 996        997          3395          389  2005-06-01 22:41:57         1
# 997        998          4433          413  2005-06-03 06:05:10         2
# 998        999          1774          332  2005-06-08 19:42:56         2
# 999       1000          1498           64  2005-06-06 06:14:31         2
#
#              last_update Hora_rental Mes_rental Dia_rental       Fecha  \
# ...

# %%
data_null=[ 'year_return','return_date','Fecha','last_update']
data.drop(data_null, axis=1,inplace=True)

# %%
data
# Out:
#      rental_id  inventory_id  customer_id  staff_id Hora_rental Mes_rental  \
# 0            1           367          130         1    22:53:30         05
# 1            2          1525          459         1    22:54:33         05
# 2            3          1711          408         1    23:03:39         05
# 3            4          2452          333         2    23:04:41         05
# 4            5          2079          222         1    23:05:21         05
# ..         ...           ...          ...       ...         ...        ...
# 995        996          4243          216         2    00:08:25         05
# 996        997          3395          389         1    00:16:57         05
# 997        998          4433          413         2    00:25:10         05
# 998        999          1774          332         2    00:25:56         05
# 999       1000          1498           64         2    00:46:31         05
#
#     Dia_rental Hora_return Mes_return Dia_return
# ...

# %%
data= data[['rental_id','inventory_id',  'customer_id', 'staff_id', 'Mes_rental', 'Dia_rental', 'Hora_rental','Mes_return','Dia_return','Hora_return']]
data
# Out:
#      rental_id  inventory_id  customer_id  staff_id Mes_rental Dia_rental  \
# 0            1           367          130         1         05         24
# 1            2          1525          459         1         05         24
# 2            3          1711          408         1         05         24
# 3            4          2452          333         2         05         24
# 4            5          2079          222         1         05         24
# ..         ...           ...          ...       ...        ...        ...
# 995        996          4243          216         2         05         31
# 996        997          3395          389         1         05         31
# 997        998          4433          413         2         05         31
# 998        999          1774          332         2         05         31
# 999       1000          1498           64         2         05         31
#
#     Hora_rental Mes_return Dia_return Hora_return
# ...

# %%
data['staff_id'].value_counts()
# Out:
# staff_id
# 2    521
# 1    479
# Name: count, dtype: int64

# %%
data.to_csv('rental_limpio.csv', index=False)rfercvferfer
